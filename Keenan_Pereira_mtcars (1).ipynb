# %% [markdown]
# IMPORTING NECESSARY LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize']=(6,4)
import seaborn as sns

# %%
df = pd.read_csv('/mtcars1.csv')

# %%
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.shape
# Out:
# (32, 12)

# %%
df.isnull().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
df['model'].isnull().sum()
# Out:
# 0

# %%
df = df.drop(['model'] , axis = 1)

# %%
df.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
df.dtypes
# Out:
# mpg     float64
# cyl       int64
# disp    float64
# hp        int64
# drat    float64
# wt      float64
# qsec    float64
# vs        int64
# am        int64
# gear      int64
# carb      int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   cyl     32 non-null     int64
#  2   disp    32 non-null     float64
#  3   hp      32 non-null     int64
#  4   drat    32 non-null     float64
#  5   wt      32 non-null     float64
#  6   qsec    32 non-null     float64
#  7   vs      32 non-null     int64
#  8   am      32 non-null     int64
#  9   gear    32 non-null     int64
#  10  carb    32 non-null     int64
# dtypes: float64(5), int64(6)
# memory usage: 2.9 KB

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# 25%    16.892500   0.000000   0.000000   3.000000   2.0000
# 50%    17.710000   0.000000   0.000000   4.000000   2.0000
# 75%    18.900000   1.000000   1.000000   4.000000   4.0000
# max    22.900000   1.000000   1.000000   5.000000   8.0000

# %%
df1 = df.drop(['am','gear','cyl','vs','carb'] , axis = 1)

# %% [markdown]
# Q1 ) HEATMAP SHOWING CORRELATION

# %%
sns.heatmap(df1.corr() , annot = True )
# Out:
# <Axes: >

# %% [markdown]
# disp hp wt have a strong negative correlation with mpg
#
# drat has a strong positive correlation with mpg

# %%
import plotly.express as px
import pandas as pd

fig = px.scatter(df, x='disp', y='mpg', labels={'disp': 'Displacement', 'mpg': 'Miles per Gallon'})

# Customize the layout
fig.update_layout(
    title='Scatter Plot of Displacement vs. Miles per Gallon',
    xaxis_title='Displacement',
    yaxis_title='Miles per Gallon',
    showlegend=False  # Set to True if you want to display legend
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="91af127a-7e77-489e-b3bf-fde287e664d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91af127a-7e77-489e-b3bf-fde287e664d9")) {                    Plotly.newPlot(                        "91af127a-7e77-489e-b3bf-fde287e664d9",                        [{"hovertemplate":"Displacement=%{x}\u003cbr\u003eMiles per Gallon=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[160.0,160.0,108.0,258.0,360.0,225.0,360.0,146.7,140.8,167.6,167.6,275.8,275.8,275.8,472.0,460.0,440.0,78.7,75.7,71.1,120.1,318.0,304.0,350.0,400.0,79.0,120.3,95.1,351.0,145.0,301.0,121.0],"xaxis":"x","y":[21.0,21.0,22.8,21.4,18.7,18.1,14.3,24.4,22.8,19.2,17.8,16.4,17.3,15.2,10.4,10.4,14.7,32.4,30.4,33.9,21.5,15.5,15.2,13.3,19.2,27.3,26.0,30.4,15.8,19.7,15.0,21.4],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar": ...

# %%
fig = px.scatter(df, x='hp', y='mpg', labels={'hp': 'Horsepower', 'mpg': 'Miles per Gallon'})

# Customize the layout
fig.update_layout(
    title='Scatter Plot of Horsepower vs. Miles per Gallon',
    xaxis_title='Horsepower',
    yaxis_title='Miles per Gallon',
    showlegend=False  # Set to True if you want to display legend
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="747c445e-6e08-4d06-b937-909eb3c8819c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("747c445e-6e08-4d06-b937-909eb3c8819c")) {                    Plotly.newPlot(                        "747c445e-6e08-4d06-b937-909eb3c8819c",                        [{"hovertemplate":"Horsepower=%{x}\u003cbr\u003eMiles per Gallon=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[110,110,93,110,175,105,245,62,95,123,123,180,180,180,205,215,230,66,52,65,97,150,150,245,175,66,91,113,264,175,335,109],"xaxis":"x","y":[21.0,21.0,22.8,21.4,18.7,18.1,14.3,24.4,22.8,19.2,17.8,16.4,17.3,15.2,10.4,10.4,14.7,32.4,30.4,33.9,21.5,15.5,15.2,13.3,19.2,27.3,26.0,30.4,15.8,19.7,15.0,21.4],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker" ...

# %%
fig = px.scatter(df, x='wt', y='mpg', labels={'wt': 'Weight', 'mpg': 'Miles per Gallon'})

# Customize the layout
fig.update_layout(
    title='Scatter Plot of Weight vs. Miles per Gallon',
    xaxis_title='Weight',
    yaxis_title='Miles per Gallon',
    showlegend=False  # Set to True if you want to display legend
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cce20ebc-ba7e-422d-86c8-0b6ea6859ab9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cce20ebc-ba7e-422d-86c8-0b6ea6859ab9")) {                    Plotly.newPlot(                        "cce20ebc-ba7e-422d-86c8-0b6ea6859ab9",                        [{"hovertemplate":"Weight=%{x}\u003cbr\u003eMiles per Gallon=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[2.62,2.875,2.32,3.215,3.44,3.46,3.57,3.19,3.15,3.44,3.44,4.07,3.73,3.78,5.25,5.424,5.345,2.2,1.615,1.835,2.465,3.52,3.435,3.84,3.845,1.935,2.14,1.513,3.17,2.77,3.57,2.78],"xaxis":"x","y":[21.0,21.0,22.8,21.4,18.7,18.1,14.3,24.4,22.8,19.2,17.8,16.4,17.3,15.2,10.4,10.4,14.7,32.4,30.4,33.9,21.5,15.5,15.2,13.3,19.2,27.3,26.0,30.4,15.8,19.7,15.0,21.4],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"# ...

# %%
fig = px.scatter(df, x='qsec', y='mpg', labels={'qsec': 'Quarter Mile Time (qsec)', 'mpg': 'Miles per Gallon'})

# Customize the layout
fig.update_layout(
    title='Scatter Plot of Quarter Mile Time vs. Miles per Gallon',
    xaxis_title='Quarter Mile Time (qsec)',
    yaxis_title='Miles per Gallon',
    showlegend=False  # Set to True if you want to display legend
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f88fb8ec-58f8-4ec3-ad19-8ae0e4520451" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f88fb8ec-58f8-4ec3-ad19-8ae0e4520451")) {                    Plotly.newPlot(                        "f88fb8ec-58f8-4ec3-ad19-8ae0e4520451",                        [{"hovertemplate":"Quarter Mile Time (qsec)=%{x}\u003cbr\u003eMiles per Gallon=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[16.46,17.02,18.61,19.44,17.02,20.22,15.84,20.0,22.9,18.3,18.9,17.4,17.6,18.0,17.98,17.82,17.42,19.47,18.52,19.9,20.01,16.87,17.3,15.41,17.05,18.9,16.7,16.9,14.5,15.5,14.6,18.6],"xaxis":"x","y":[21.0,21.0,22.8,21.4,18.7,18.1,14.3,24.4,22.8,19.2,17.8,16.4,17.3,15.2,10.4,10.4,14.7,32.4,30.4,33.9,21.5,15.5,15.2,13.3,19.2,27.3,26.0,30.4,15.8,19.7,15.0,21.4],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar" ...

# %%
fig = px.scatter(df, x='drat', y='mpg', labels={'drat': 'Rear Axle Ratio (drat)', 'mpg': 'Miles per Gallon'})

# Customize the layout
fig.update_layout(
    title='Scatter Plot of Rear Axle Ratio vs. Miles per Gallon',
    xaxis_title='Rear Axle Ratio (drat)',
    yaxis_title='Miles per Gallon',
    showlegend=False  # Set to True if you want to display legend
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f6f1fa3a-0fba-4ce4-8f6c-b634d286d53f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6f1fa3a-0fba-4ce4-8f6c-b634d286d53f")) {                    Plotly.newPlot(                        "f6f1fa3a-0fba-4ce4-8f6c-b634d286d53f",                        [{"hovertemplate":"Rear Axle Ratio (drat)=%{x}\u003cbr\u003eMiles per Gallon=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[3.9,3.9,3.85,3.08,3.15,2.76,3.21,3.69,3.92,3.92,3.92,3.07,3.07,3.07,2.93,3.0,3.23,4.08,4.93,4.22,3.7,2.76,3.15,3.73,3.08,4.08,4.43,3.77,4.22,3.62,3.54,4.11],"xaxis":"x","y":[21.0,21.0,22.8,21.4,18.7,18.1,14.3,24.4,22.8,19.2,17.8,16.4,17.3,15.2,10.4,10.4,14.7,32.4,30.4,33.9,21.5,15.5,15.2,13.3,19.2,27.3,26.0,30.4,15.8,19.7,15.0,21.4],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color": ...

# %%
x =df.drop(['mpg'],axis=1)
#independent variable

# %%
y = df['mpg']
#dependent variable

# %% [markdown]
# MODEL BUILDING

# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=101 )

# %%
print('y target size:', len(y_train))
print('x train size:', len(x_train))
print('x test size:',len(x_test))
print('y target size:', len(y_test))
# Out:
# y target size: 25
# x train size: 25
# x test size: 7
# y target size: 7

# %%
x_train = sm.add_constant(x_train)
x_train.head()
# Out:
#     const  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 26    1.0    4  120.3   91  4.43  2.140  16.70   0   1     5     2
# 24    1.0    8  400.0  175  3.08  3.845  17.05   0   0     3     2
# 16    1.0    8  440.0  230  3.23  5.345  17.42   0   0     3     4
# 18    1.0    4   75.7   52  4.93  1.615  18.52   1   1     4     2
# 10    1.0    6  167.6  123  3.92  3.440  18.90   1   0     4     4

# %%
x_train.shape
# Out:
# (25, 11)

# %%
x_test= sm.add_constant(x_test)
x_test.head()
# Out:
#     const  cyl   disp   hp  drat     wt  qsec  vs  am  gear  carb
# 7     1.0    4  146.7   62  3.69  3.190  20.0   1   0     4     2
# 29    1.0    6  145.0  175  3.62  2.770  15.5   0   1     5     6
# 28    1.0    8  351.0  264  4.22  3.170  14.5   0   1     5     4
# 25    1.0    4   79.0   66  4.08  1.935  18.9   1   1     4     1
# 19    1.0    4   71.1   65  4.22  1.835  19.9   1   1     4     1

# %%
x_test.shape
# Out:
# (7, 11)

# %%
y_train[:5]
# Out:
# 26    26.0
# 24    19.2
# 16    14.7
# 18    30.4
# 10    17.8
# Name: mpg, dtype: float64

# %%
y_train.head()
# Out:
# 26    26.0
# 24    19.2
# 16    14.7
# 18    30.4
# 10    17.8
# Name: mpg, dtype: float64

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
from sklearn import metrics
scores = pd.DataFrame(columns=['Model','MAE_Train','MSE_Train','RMSE_Train','MAPE_Train','MAE_Test','MSE_Test','RMSE_Test','MAPE_Test','R^2'])


#definition of error metrics function
def get_metrics(train_act,train_pred,test_act,test_pred,model_description,dataframe):
    MAE_Train = metrics.mean_absolute_error(train_act,train_pred)
    MSE_Train = metrics.mean_squared_error(train_act,train_pred)
    RMSE_Train = np.sqrt(metrics.mean_squared_error(train_act,train_pred))
    MAPE_Train = mean_absolute_percentage_error(train_act,train_pred)
    MAE_Test = metrics.mean_absolute_error(test_act,test_pred)
    MSE_Test = metrics.mean_squared_error(test_act,test_pred)
    RMSE_Test = np.sqrt(metrics.mean_squared_error(test_act,test_pred))
    MAPE_Test = mean_absolute_percentage_error(test_act,test_pred)
    R2=metrics.r2_score(train_act,train_pred)
    s1=pd.Series([model_description,MAE_Train,MSE_Train,RMSE_Train,MAPE_Train,MAE_Test,MSE_Test,RMSE_Test,MAPE_Test,R2],
                                           index=scores.columns)
    dataframe = dataframe.append(s1, ignore_index=True)
    return(dataframe)

# %%
#definition of coefficient function
def coeff(model_title,modelparams):
    tempdf=pd.DataFrame(modelparams)
    tempdf.rename(columns = {0:model_title},inplace = True)
    DF=pd.concat([coefficients,tempdf],axis=1)
    return(DF)

# %% [markdown]
# Q2 ) SIMPLE LINEAR MODELS

# %%
model1=sm.OLS(y_train,x_train[['const','disp']]).fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.703
# Model:                            OLS   Adj. R-squared:                  0.690
# Method:                 Least Squares   F-statistic:                     54.35
# Date:                Tue, 10 Oct 2023   Prob (F-statistic):           1.69e-07
# Time:                        13:32:10   Log-Likelihood:                -63.692
# No. Observations:                  25   AIC:                             131.4
# Df Residuals:                      23   BIC:                             133.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         28.9752      1.457     19.883      0.000      25.961      31.990
# disp          -0.0391      0.005     -7.373      0.000      -0.050      -0.028
# ==============================================================================
# Omnibus:                        3.233   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.199   Jarque-Bera (JB):                2.747
# Skew:                           0.730   Prob(JB):                        0.253
# Kurtosis:                       2.289   Cond. No.                         621.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#get coefficients
coefficients=pd.DataFrame(model1.params)
coefficients.rename(columns = {0:"Simple_Linear_Regression"},inplace = True)
coefficients
# Out:
#        Simple_Linear_Regression
# const                 28.975242
# disp                  -0.039077

# %%
scores1 = get_metrics (y_train , model1.predict(x_train[['const','disp']]),
                      y_test,model1.predict(x_test[['const','disp']]),"Simple Linear Regression (disp)",scores)
scores1
# Out:
# <ipython-input-31-684a30b8e91b>:18: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                              Model  MAE_Train  MSE_Train  RMSE_Train  \
# 0  Simple Linear Regression (disp)   2.625809    9.55907    3.091775
#
#    MAPE_Train  MAE_Test   MSE_Test  RMSE_Test  MAPE_Test       R^2
# 0   13.187245  2.489408  11.558649   3.399801   9.960172  0.702669

# %%
model2=sm.OLS(y_train,x_train[['const','qsec']]).fit()
print(model2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.094
# Model:                            OLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     2.397
# Date:                Tue, 10 Oct 2023   Prob (F-statistic):              0.135
# Time:                        13:32:10   Log-Likelihood:                -77.614
# No. Observations:                  25   AIC:                             159.2
# Df Residuals:                      23   BIC:                             161.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8330     12.007      0.069      0.945     -24.005      25.671
# qsec           1.0353      0.669      1.548      0.135      -0.348       2.419
# ==============================================================================
# Omnibus:                        3.928   Durbin-Watson:                   2.237
# Prob(Omnibus):                  0.140   Jarque-Bera (JB):                2.653
# Skew:                           0.791   Prob(JB):                        0.265
# Kurtosis:                       3.211   Cond. No.                         192.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#get coefficients
coefficients=pd.DataFrame(model2.params)
coefficients.rename(columns = {0:"Simple_Linear_Regression"},inplace = True)
coefficients
# Out:
#        Simple_Linear_Regression
# const                  0.833026
# qsec                   1.035344

# %%
scores2 = get_metrics (y_train , model2.predict(x_train[['const','qsec']]),
                      y_test,model2.predict(x_test[['const','qsec']]),"Simple Linear Regression (qsec)",scores)
scores2
# Out:
# <ipython-input-31-684a30b8e91b>:18: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                              Model  MAE_Train  MSE_Train  RMSE_Train  \
# 0  Simple Linear Regression (qsec)   4.010205  29.115513    5.395879
#
#    MAPE_Train  MAE_Test   MSE_Test  RMSE_Test  MAPE_Test       R^2
# 0   22.227659  4.369411  33.455682   5.784089  16.893654  0.094374

# %%
model3=sm.OLS(y_train,x_train[['const','wt']]).fit()
print(model3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.781
# Model:                            OLS   Adj. R-squared:                  0.771
# Method:                 Least Squares   F-statistic:                     81.99
# Date:                Tue, 10 Oct 2023   Prob (F-statistic):           4.81e-09
# Time:                        13:32:10   Log-Likelihood:                -59.874
# No. Observations:                  25   AIC:                             123.7
# Df Residuals:                      23   BIC:                             126.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         36.4061      1.964     18.533      0.000      32.343      40.470
# wt            -5.0664      0.560     -9.055      0.000      -6.224      -3.909
# ==============================================================================
# Omnibus:                        3.872   Durbin-Watson:                   1.807
# Prob(Omnibus):                  0.144   Jarque-Bera (JB):                2.286
# Skew:                           0.692   Prob(JB):                        0.319
# Kurtosis:                       3.526   Cond. No.                         13.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#get coefficients
coefficients=pd.DataFrame(model3.params)
coefficients.rename(columns = {0:"Simple_Linear_Regression"},inplace = True)
coefficients
# Out:
#        Simple_Linear_Regression
# const                 36.406098
# wt                    -5.066409

# %%
scores3 = get_metrics (y_train , model3.predict(x_train[['const','wt']]),
                     y_test,model3.predict(x_test[['const','wt']]),"Simple Linear Regression (wt)",scores)
scores3
# Out:
# <ipython-input-31-684a30b8e91b>:18: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                            Model  MAE_Train  MSE_Train  RMSE_Train  \
# 0  Simple Linear Regression (wt)   2.047868   7.043257    2.653913
#
#    MAPE_Train  MAE_Test   MSE_Test  RMSE_Test  MAPE_Test       R^2
# 0   11.413679  3.398001  14.934714   3.864546  15.699463  0.780922

# %% [markdown]
# Q3 ) CATEGORICAL LINEAR MODELS

# %%
model4=sm.OLS(y_train,x_train[['const','gear']]).fit()
print(model4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.345
# Model:                            OLS   Adj. R-squared:                  0.316
# Method:                 Least Squares   F-statistic:                     12.10
# Date:                Tue, 10 Oct 2023   Prob (F-statistic):            0.00203
# Time:                        13:32:10   Log-Likelihood:                -73.571
# No. Observations:                  25   AIC:                             151.1
# Df Residuals:                      23   BIC:                             153.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.3480      4.978      0.472      0.642      -7.950      12.647
# gear           4.7730      1.372      3.478      0.002       1.934       7.612
# ==============================================================================
# Omnibus:                        1.899   Durbin-Watson:                   1.836
# Prob(Omnibus):                  0.387   Jarque-Bera (JB):                0.658
# Skew:                           0.137   Prob(JB):                        0.719
# Kurtosis:                       3.746   Cond. No.                         20.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#get coefficients
coefficients=pd.DataFrame(model4.params)
coefficients.rename(columns = {0:"Categorical_Linear_Regression"},inplace = True)
coefficients
# Out:
#        Categorical_Linear_Regression
# const                       2.348026
# gear                        4.773026

# %%
scores4 = get_metrics (y_train , model4.predict(x_train[['const','gear']]),
                      y_test,model4.predict(x_test[['const','gear']]),"Categorical Linear Regression (gear)",scores)
scores4
# Out:
# <ipython-input-31-684a30b8e91b>:18: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                                   Model  MAE_Train  MSE_Train  RMSE_Train  \
# 0  Categorical Linear Regression (gear)   3.333105  21.068542    4.590048
#
#    MAPE_Train  MAE_Test   MSE_Test  RMSE_Test  MAPE_Test       R^2
# 0   18.881853  5.818985  50.344809   7.095408  26.115989  0.344672

# %%
model6=sm.OLS(y_train,x_train[['const','am']]).fit()
print(model6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.421
# Model:                            OLS   Adj. R-squared:                  0.395
# Method:                 Least Squares   F-statistic:                     16.69
# Date:                Tue, 10 Oct 2023   Prob (F-statistic):           0.000455
# Time:                        13:32:10   Log-Likelihood:                -72.033
# No. Observations:                  25   AIC:                             148.1
# Df Residuals:                      23   BIC:                             150.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         16.8176      1.091     15.409      0.000      14.560      19.075
# am             7.8824      1.929      4.086      0.000       3.891      11.874
# ==============================================================================
# Omnibus:                        0.356   Durbin-Watson:                   1.643
# Prob(Omnibus):                  0.837   Jarque-Bera (JB):                0.514
# Skew:                          -0.188   Prob(JB):                        0.773
# Kurtosis:                       2.406   Cond. No.                         2.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
scores6 = get_metrics (y_train , model6.predict(x_train[['const','am']]),
                     y_test,model6.predict(x_test[['const','am']]),"Categorical Linear Regression (am)",scores)
scores6
# Out:
# <ipython-input-31-684a30b8e91b>:18: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                                 Model  MAE_Train  MSE_Train  RMSE_Train  \
# 0  Categorical Linear Regression (am)   3.603294  18.629788    4.316224
#
#    MAPE_Train  MAE_Test   MSE_Test  RMSE_Test  MAPE_Test       R^2
# 0   20.280095  5.214286  36.921181    6.07628  23.754539  0.420528

# %%
model7=sm.OLS(y_train,x_train[['const','cyl']]).fit()
print(model7.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.712
# Model:                            OLS   Adj. R-squared:                  0.700
# Method:                 Least Squares   F-statistic:                     56.89
# Date:                Tue, 10 Oct 2023   Prob (F-statistic):           1.16e-07
# Time:                        13:32:11   Log-Likelihood:                -63.289
# No. Observations:                  25   AIC:                             130.6
# Df Residuals:                      23   BIC:                             133.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         37.3844      2.475     15.105      0.000      32.264      42.504
# cyl           -2.8194      0.374     -7.543      0.000      -3.593      -2.046
# ==============================================================================
# Omnibus:                        0.704   Durbin-Watson:                   2.187
# Prob(Omnibus):                  0.703   Jarque-Bera (JB):                0.718
# Skew:                           0.169   Prob(JB):                        0.699
# Kurtosis:                       2.242   Cond. No.                         26.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
scores7 = get_metrics (y_train , model7.predict(x_train[['const','cyl']]),
                     y_test,model7.predict(x_test[['const','cyl']]),"Categorical Linear Regression (cyl)",scores)
scores7
# Out:
# <ipython-input-31-684a30b8e91b>:18: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                                  Model  MAE_Train  MSE_Train  RMSE_Train  \
# 0  Categorical Linear Regression (cyl)   2.405956   9.255711     3.04232
#
#    MAPE_Train  MAE_Test   MSE_Test  RMSE_Test  MAPE_Test       R^2
# 0   12.987861  2.344286  11.141396   3.337873   9.033028  0.712105

# %% [markdown]
# Q4 ) MULTIPLE LINEAR MODEL

# %% [markdown]
# DUMMIFICATION

# %%
#Dummification
x_train = pd.get_dummies(x_train,drop_first=True,dtype='int8')
x_test = pd.get_dummies(x_test,drop_first=True,dtype='int8')

# %%
x_train.head() #snapshot of X train
# Out:
#     const  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 26    1.0    4  120.3   91  4.43  2.140  16.70   0   1     5     2
# 24    1.0    8  400.0  175  3.08  3.845  17.05   0   0     3     2
# 16    1.0    8  440.0  230  3.23  5.345  17.42   0   0     3     4
# 18    1.0    4   75.7   52  4.93  1.615  18.52   1   1     4     2
# 10    1.0    6  167.6  123  3.92  3.440  18.90   1   0     4     4

# %%
print(x_train.columns)
print("\n")
print(x_test.columns)
print("\n")
print("\n No. of columns in Train Data :{}".format(len(x_train.columns)))
print("\n No. of columns in Test Data :{}".format(len(x_test.columns)))
# Out:
# Index(['const', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')
#
#
# Index(['const', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')
#
#
#
#  No. of columns in Train Data :11
#
#  No. of columns in Test Data :11

# %%
multiple_reg1 = sm.OLS(y_train, x_train).fit()
print(multiple_reg1.summary()) #build a model using all attributes
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.914
# Model:                            OLS   Adj. R-squared:                  0.852
# Method:                 Least Squares   F-statistic:                     14.85
# Date:                Tue, 10 Oct 2023   Prob (F-statistic):           8.51e-06
# Time:                        13:32:11   Log-Likelihood:                -48.209
# No. Observations:                  25   AIC:                             118.4
# Df Residuals:                      14   BIC:                             131.8
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -15.0575     23.297     -0.646      0.529     -65.025      34.910
# cyl            1.6741      1.208      1.386      0.187      -0.916       4.264
# disp           0.0052      0.015      0.341      0.738      -0.028       0.038
# hp             0.0033      0.021      0.156      0.878      -0.042       0.049
# drat           3.0022      1.935      1.552      0.143      -1.148       7.152
# wt            -2.2125      1.678     -1.319      0.208      -5.811       1.386
# qsec           0.7085      0.699      1.013      0.328      -0.791       2.208
# vs             2.2650      1.901      1.192      0.253      -1.811       6.341
# am             4.4225      2.205      2.006      0.065      -0.307       9.152
# gear           2.7747      1.589      1.746      0.103      -0.633       6.183
# carb          -2.1137      0.958     -2.206      0.045      -4.169      -0.059
# ==============================================================================
# Omnibus:                        2.282   Durbin-Watson:                   1.602
# Prob(Omnibus):                  0.320   Jarque-Bera (JB):                0.958
# Skew:                          -0.357   Prob(JB):                        0.620
# Kurtosis:                       3.641   Cond. No.                     1.68e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.68e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# am carb gear cyl drat are top 5 most important features

# %%
#get Coefficients
coefficients=coeff("MLR_with_all_attributes",multiple_reg1.params)
coefficients
# Out:
#        Categorical_Linear_Regression  MLR_with_all_attributes
# const                       2.348026               -15.057502
# gear                        4.773026                 2.774741
# cyl                              NaN                 1.674058
# disp                             NaN                 0.005234
# hp                               NaN                 0.003330
# drat                             NaN                 3.002229
# wt                               NaN                -2.212533
# qsec                             NaN                 0.708473
# vs                               NaN                 2.264985
# am                               NaN                 4.422467
# carb                             NaN                -2.113711

# %%
#get error metrics
scores = get_metrics(y_train,multiple_reg1.predict(x_train),y_test,multiple_reg1.predict(x_test),"MLR_with_all_attributes",scores)
scores
# Out:
# <ipython-input-31-684a30b8e91b>:18: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                      Model  MAE_Train  MSE_Train  RMSE_Train  MAPE_Train  \
# 0  MLR_with_all_attributes   1.233768    2.76994    1.664314     6.80851
#
#    MAE_Test   MSE_Test  RMSE_Test  MAPE_Test       R^2
# 0  4.193637  26.815954   5.178412  21.043919  0.913842

# %% [markdown]
# Q5 ) STANDARDIZATION

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler = StandardScaler() #importing Scaler

# %%
df.head(3)
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1

# %%
num_vars = ['disp', 'qsec', 'wt',
       'hp' , 'drat'   ] #defining Numerical variable

# %%
scaler = StandardScaler()
x_train[num_vars] = scaler.fit_transform(x_train[num_vars])
x_test[num_vars] = scaler.transform(x_test[num_vars])

print(x_train.head())
#Scaling
# Out:
#     const  cyl      disp        hp      drat        wt      qsec  vs  am  \
# 26    1.0    4 -1.038156 -0.944062  1.668935 -1.242157 -0.698526   0   1
# 24    1.0    8  1.261422  0.339960 -0.879778  0.481825 -0.490489   0   0
# 16    1.0    8  1.590285  1.180689 -0.596588  1.998526 -0.270566   0   0
# 18    1.0    4 -1.404839 -1.540215  2.612903 -1.773002  0.383262   1   1
# 10    1.0    6 -0.649275 -0.454911  0.706088  0.072316  0.609129   1   0
#
#     gear  carb
# 26     5     2
# 24     3     2
# 16     3     4
# 18     4     2
# 10     4     4

# %%
# adding the Constant term
x_train = sm.add_constant(x_train)
print(x_train.head())

x_test = sm.add_constant(x_test)
#X_test.head()
# Out:
#     const  cyl      disp        hp      drat        wt      qsec  vs  am  \
# 26    1.0    4 -1.038156 -0.944062  1.668935 -1.242157 -0.698526   0   1
# 24    1.0    8  1.261422  0.339960 -0.879778  0.481825 -0.490489   0   0
# 16    1.0    8  1.590285  1.180689 -0.596588  1.998526 -0.270566   0   0
# 18    1.0    4 -1.404839 -1.540215  2.612903 -1.773002  0.383262   1   1
# 10    1.0    6 -0.649275 -0.454911  0.706088  0.072316  0.609129   1   0
#
#     gear  carb
# 26     5     2
# 24     3     2
# 16     3     4
# 18     4     2
# 10     4     4

# %%
x_train = pd.get_dummies(x_train,drop_first=True,dtype='int8')
x_test = pd.get_dummies(x_test,drop_first=True,dtype='int8') #dummification

# %%
multiple_reg3= sm.OLS(y_train, x_train).fit()
print(multiple_reg3.summary()) #build a regression model
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.914
# Model:                            OLS   Adj. R-squared:                  0.852
# Method:                 Least Squares   F-statistic:                     14.85
# Date:                Tue, 10 Oct 2023   Prob (F-statistic):           8.51e-06
# Time:                        13:32:11   Log-Likelihood:                -48.209
# No. Observations:                  25   AIC:                             118.4
# Df Residuals:                      14   BIC:                             131.8
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.5988     10.431      0.249      0.807     -19.774      24.971
# cyl            1.6741      1.208      1.386      0.187      -0.916       4.264
# disp           0.6366      1.867      0.341      0.738      -3.368       4.641
# hp             0.2178      1.395      0.156      0.878      -2.774       3.210
# drat           1.5902      1.025      1.552      0.143      -0.608       3.788
# wt            -2.1882      1.659     -1.319      0.208      -5.747       1.371
# qsec           1.1919      1.176      1.013      0.328      -1.331       3.715
# vs             2.2650      1.901      1.192      0.253      -1.811       6.341
# am             4.4225      2.205      2.006      0.065      -0.307       9.152
# gear           2.7747      1.589      1.746      0.103      -0.633       6.183
# carb          -2.1137      0.958     -2.206      0.045      -4.169      -0.059
# ==============================================================================
# Omnibus:                        2.282   Durbin-Watson:                   1.602
# Prob(Omnibus):                  0.320   Jarque-Bera (JB):                0.958
# Skew:                          -0.357   Prob(JB):                        0.620
# Kurtosis:                       3.641   Cond. No.                         194.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#get error metrics
scores = get_metrics(y_train,multiple_reg3.predict( x_train),y_test,multiple_reg3.predict(x_test),"MLR_after_standardization",scores)
scores
# Out:
# <ipython-input-31-684a30b8e91b>:18: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                        Model  MAE_Train  MSE_Train  RMSE_Train  MAPE_Train  \
# 0    MLR_with_all_attributes   1.233768    2.76994    1.664314     6.80851
# 1  MLR_after_standardization   1.233768    2.76994    1.664314     6.80851
#
#    MAE_Test   MSE_Test  RMSE_Test  MAPE_Test       R^2
# 0  4.193637  26.815954   5.178412  21.043919  0.913842
# 1  4.193637  26.815954   5.178412  21.043919  0.913842

# %%
#get coefficients
coefficients=coeff("MLR_after_standardization",multiple_reg3.params)
coefficients
# Out:
#        Categorical_Linear_Regression  MLR_with_all_attributes  \
# const                       2.348026               -15.057502
# gear                        4.773026                 2.774741
# cyl                              NaN                 1.674058
# disp                             NaN                 0.005234
# hp                               NaN                 0.003330
# drat                             NaN                 3.002229
# wt                               NaN                -2.212533
# qsec                             NaN                 0.708473
# vs                               NaN                 2.264985
# am                               NaN                 4.422467
# carb                             NaN                -2.113711
#
#        MLR_after_standardization
# const                   2.598804
# gear                    2.774741
# cyl                     1.674058
# disp                    0.636599
# hp                      0.217834
# drat                    1.590218
# wt                     -2.188170
# qsec                    1.191935
# vs                      2.264985
# am                      4.422467
# carb                   -2.113711

# %% [markdown]
# Q7 ) REMOVING OUTLIERS

# %%
import matplotlib.pyplot as plt

# List of columns for which you want to create box plots
columns_to_plot = ['qsec', 'hp', 'wt']

# Create box plots using a loop
for column in columns_to_plot:
    plt.figure(figsize=(8, 6))
    plt.boxplot(df[column])
    plt.title(f'Box plot for {column}')
    plt.ylabel('Values')
    plt.show()

# %%
df = df[df['qsec'] < 21 ]

# %%
df = df[df['hp'] < 300]

# %%
df = df[df['wt'] < 4.5 ]

# %%
x = df.drop(['mpg'],axis=1)

# %%
y = df['mpg']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=101)

# %%
print('y target size:', len(y_train))
print('x train size:', len(x_train))
print('x test size:',len(x_test))
print('y target size:',len(y_test))
# Out:
# y target size: 21
# x train size: 21
# x test size: 6
# y target size: 6

# %%
x_train = sm.add_constant(x_train)
x_train.head()
# Out:
#     const  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 2     1.0    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 7     1.0    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 3     1.0    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 1     1.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 20    1.0    4  120.1   97  3.70  2.465  20.01   1   0     3     1

# %%
x_test= sm.add_constant(x_test)
x_test.head()
# Out:
#     const  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 29    1.0    6  145.0  175  3.62  2.770  15.50   0   1     5     6
# 26    1.0    4  120.3   91  4.43  2.140  16.70   0   1     5     2
# 28    1.0    8  351.0  264  4.22  3.170  14.50   0   1     5     4
# 24    1.0    8  400.0  175  3.08  3.845  17.05   0   0     3     2
# 11    1.0    8  275.8  180  3.07  4.070  17.40   0   0     3     3

# %%
multiple_reg4= sm.OLS(y_train, x_train).fit()
print(multiple_reg4.summary()) #build a regression model
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     13.85
# Date:                Tue, 10 Oct 2023   Prob (F-statistic):           0.000138
# Time:                        13:32:12   Log-Likelihood:                -38.221
# No. Observations:                  21   AIC:                             98.44
# Df Residuals:                      10   BIC:                             109.9
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -85.1596     37.150     -2.292      0.045    -167.934      -2.385
# cyl            0.7276      1.246      0.584      0.572      -2.048       3.503
# disp           0.0511      0.029      1.784      0.105      -0.013       0.115
# hp             0.0128      0.029      0.445      0.666      -0.051       0.077
# drat           2.0082      2.395      0.839      0.421      -3.327       7.344
# wt            -8.8583      2.660     -3.330      0.008     -14.785      -2.931
# qsec           4.7156      1.570      3.003      0.013       1.217       8.214
# vs            -4.6760      3.171     -1.475      0.171     -11.741       2.389
# am             1.0729      2.666      0.402      0.696      -4.867       7.013
# gear           7.2320      2.529      2.860      0.017       1.598      12.866
# carb           0.0126      1.359      0.009      0.993      -3.015       3.041
# ==============================================================================
# Omnibus:                        3.476   Durbin-Watson:                   1.601
# Prob(Omnibus):                  0.176   Jarque-Bera (JB):                1.901
# Skew:                           0.707   Prob(JB):                        0.387
# Kurtosis:                       3.415   Cond. No.                     1.93e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.93e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#get error metrics
scores = get_metrics(y_train,multiple_reg4.predict( x_train),y_test,multiple_reg4.predict(x_test),"MLR_after_Outlier_treatment",scores)
scores
# Out:
# <ipython-input-31-684a30b8e91b>:18: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                          Model  MAE_Train  MSE_Train  RMSE_Train  MAPE_Train  \
# 0      MLR_with_all_attributes   1.233768   2.769940    1.664314    6.808510
# 1    MLR_after_standardization   1.233768   2.769940    1.664314    6.808510
# 2  MLR_after_Outlier_treatment   1.155745   2.230477    1.493478    5.801718
#
#    MAE_Test   MSE_Test  RMSE_Test  MAPE_Test       R^2
# 0  4.193637  26.815954   5.178412  21.043919  0.913842
# 1  4.193637  26.815954   5.178412  21.043919  0.913842
# 2  5.051285  37.677355   6.138188  29.647128  0.932669

# %%
#get coefficients
coefficients=coeff("MLR_after_outlier_treatment",multiple_reg3.params)
coefficients
# Out:
#        Categorical_Linear_Regression  MLR_with_all_attributes  \
# const                       2.348026               -15.057502
# gear                        4.773026                 2.774741
# cyl                              NaN                 1.674058
# disp                             NaN                 0.005234
# hp                               NaN                 0.003330
# drat                             NaN                 3.002229
# wt                               NaN                -2.212533
# qsec                             NaN                 0.708473
# vs                               NaN                 2.264985
# am                               NaN                 4.422467
# carb                             NaN                -2.113711
#
#        MLR_after_standardization  MLR_after_outlier_treatment
# const                   2.598804                     2.598804
# gear                    2.774741                     2.774741
# cyl                     1.674058                     1.674058
# disp                    0.636599                     0.636599
# hp                      0.217834                     0.217834
# drat                    1.590218                     1.590218
# wt                     -2.188170                    -2.188170
# qsec                    1.191935                     1.191935
# vs                      2.264985                     2.264985
# am                      4.422467                     4.422467
# carb                   -2.113711                    -2.113711

# %% [markdown]
# Q8 ) BUILDING A MODEL USING RFE

# %%
from sklearn.feature_selection import RFE #import RFE

# %%
# Python style of Linear Regression model
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
indp_vars = x
min_aic = 10**100 # initiailizing AIC to a very large value
for i in range(indp_vars.shape[1],0,-1):
    regression_model = LinearRegression()
    rfe = RFE(regression_model, n_features_to_select=i)
    rfe = rfe.fit(x_train, y_train)
    chk = x_train.loc[:,list(rfe.support_)]
    print(chk.columns)
    regression_model=sm.OLS(y_train,chk)
    result=regression_model.fit()
    current_aic = result.aic
    print(current_aic)
    if(current_aic <= min_aic):
        min_aic = current_aic
        bestmodel = chk.columns
    else:
        print("Break !")
        break
# Out:
# Index(['cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb'], dtype='object')
# 105.31042246364898
# Index(['cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear'], dtype='object')
# 103.33734949068574
# Index(['cyl', 'disp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear'], dtype='object')
# 102.27387651235655
# Index(['cyl', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear'], dtype='object')
# 100.8498625961204
# Index(['cyl', 'drat', 'wt', 'qsec', 'vs', 'gear'], dtype='object')
# 98.89386205663698
# Index(['cyl', 'wt', 'qsec', 'vs', 'gear'], dtype='object')
# 96.95605185616131
# Index(['wt', 'qsec', 'vs', 'gear'], dtype='object')
# 95.88580020887102
# Index(['wt', 'vs', 'gear'], dtype='object')
# 118.01318493378261
# Break !

# %%
bestmodel_data = x_train.loc[:,bestmodel]
bestmodel_data_test = x_test.loc[:,bestmodel]
bestmodel_data['const'] =1
bestmodel_data_test['const'] =1
bestmodel_data.head() #splitt data using bestmodel data
# Out:
#        wt   qsec  vs  gear  const
# 2   2.320  18.61   1     4      1
# 7   3.190  20.00   1     4      1
# 3   3.215  19.44   1     3      1
# 1   2.875  17.02   0     4      1
# 20  2.465  20.01   1     3      1

# %%
regression_model=sm.OLS(y_train,bestmodel_data).fit()
print(regression_model.summary2()) #build a regression model
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.856
# Dependent Variable: mpg              AIC:                97.6870
# Date:               2023-10-10 13:32 BIC:                102.9096
# No. Observations:   21               Log-Likelihood:     -43.844
# Df Model:           4                F-statistic:        30.78
# Df Residuals:       16               Prob (F-statistic): 2.48e-07
# R-squared:          0.885            Scale:              5.0010
# -------------------------------------------------------------------
#           Coef.    Std.Err.      t      P>|t|     [0.025     0.975]
# -------------------------------------------------------------------
# wt       -6.0997     1.0185   -5.9889   0.0000    -8.2588   -3.9406
# qsec      2.0910     0.7886    2.6517   0.0174     0.4194    3.7627
# vs       -3.3929     2.4245   -1.3994   0.1808    -8.5325    1.7468
# gear      2.7588     1.4470    1.9065   0.0747    -0.3088    5.8265
# const    -6.7039    17.1853   -0.3901   0.7016   -43.1351   29.7273
# -----------------------------------------------------------------
# Omnibus:              0.639        Durbin-Watson:           1.920
# Prob(Omnibus):        0.726        Jarque-Bera (JB):        0.681
# Skew:                 0.211        Prob(JB):                0.711
# Kurtosis:             2.226        Condition No.:           673
# =================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the
# errors is correctly specified.

# %%
#get coefficients
coefficients=coeff("MLR_after_RFE",regression_model.params)
coefficients
# Out:
#        Categorical_Linear_Regression  MLR_with_all_attributes  \
# const                       2.348026               -15.057502
# gear                        4.773026                 2.774741
# cyl                              NaN                 1.674058
# disp                             NaN                 0.005234
# hp                               NaN                 0.003330
# drat                             NaN                 3.002229
# wt                               NaN                -2.212533
# qsec                             NaN                 0.708473
# vs                               NaN                 2.264985
# am                               NaN                 4.422467
# carb                             NaN                -2.113711
#
#        MLR_after_standardization  MLR_after_outlier_treatment  MLR_after_RFE
# const                   2.598804                     2.598804      -6.703900
# gear                    2.774741                     2.774741       2.758848
# cyl                     1.674058                     1.674058            NaN
# disp                    0.636599                     0.636599            NaN
# hp                      0.217834                     0.217834            NaN
# drat                    1.590218                     1.590218            NaN
# wt                     -2.188170                    -2.188170      -6.099687
# qsec                    1.191935                     1.191935       2.091027
# vs                      2.264985                     2.264985      -3.392859
# am                      4.422467                     4.422467            NaN
# carb                   -2.113711                    -2.113711            NaN

# %%
bestmodel_data.columns
# Out:
# Index(['wt', 'qsec', 'vs', 'gear', 'const'], dtype='object')

# %%
#get error metrics
scores = get_metrics(y_train,regression_model.predict(bestmodel_data),y_test,regression_model.predict(bestmodel_data_test),"MLR_after_RFE",scores)
scores
# Out:
# <ipython-input-31-684a30b8e91b>:18: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                          Model  MAE_Train  MSE_Train  RMSE_Train  MAPE_Train  \
# 0      MLR_with_all_attributes   1.233768   2.769940    1.664314    6.808510
# 1    MLR_after_standardization   1.233768   2.769940    1.664314    6.808510
# 2  MLR_after_Outlier_treatment   1.155745   2.230477    1.493478    5.801718
# 3                MLR_after_RFE   1.700125   3.810251    1.951986    7.933231
#
#    MAE_Test   MSE_Test  RMSE_Test  MAPE_Test       R^2
# 0  4.193637  26.815954   5.178412  21.043919  0.913842
# 1  4.193637  26.815954   5.178412  21.043919  0.913842
# 2  5.051285  37.677355   6.138188  29.647128  0.932669
# 3  3.293632  11.847395   3.442004  18.455579  0.884980

# %% [markdown]
# Q9 )  BUILDING MODEL USING VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X = df.drop(columns=['mpg'])
vif = pd.DataFrame()
vif["Variable"] = X.columns
vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif)
# Out:
#   Variable         VIF
# 0      cyl  246.236513
# 1     disp  110.047305
# 2       hp   53.969500
# 3     drat  152.666921
# 4       wt  192.732886
# 5     qsec  424.693875
# 6       vs    9.986902
# 7       am   11.539079
# 8     gear  112.315818
# 9     carb   32.024267

# %%
vif.sort_values(by='VIF',ascending=False) #sort VIF data
# Out:
#   Variable         VIF
# 5     qsec  424.693875
# 0      cyl  246.236513
# 4       wt  192.732886
# 3     drat  152.666921
# 8     gear  112.315818
# 1     disp  110.047305
# 2       hp   53.969500
# 9     carb   32.024267
# 7       am   11.539079
# 6       vs    9.986902

# %%
high_vif_variables = vif[vif['VIF'] >200 ]['Variable']
X = X.drop(columns=high_vif_variables)

# %%
x_VIF = X
y_VIF = df['mpg']

import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# ** Use model_selection.train_test_split from sklearn to split the data into training and testing sets. Set test_size=0.3 and random_state=101**

## Split the data into Training and Testing Data
x_train_VIF, x_test_VIF, y_train_VIF, y_test_VIF = train_test_split(x_VIF, y_VIF, test_size=0.2, random_state=101)

len(y_train)
print('Y Target Size:', len(y_train_VIF))
print('X Train Size:', len(x_train_VIF))
print('X Test  Size:', len(x_test_VIF))
print('Y Target Size:', len(y_test_VIF))


# adding the Constant term
X_train_VIF= sm.add_constant(x_train_VIF)
X_test_VIF= sm.add_constant(x_test_VIF)
# Out:
# Y Target Size: 21
# X Train Size: 21
# X Test  Size: 6
# Y Target Size: 6

# %%
multiple_reg_VIF= sm.OLS(y_train_VIF, X_train_VIF).fit()
print(multiple_reg_VIF.summary())#build regression model
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.781
# Method:                 Least Squares   F-statistic:                     9.910
# Date:                Tue, 10 Oct 2023   Prob (F-statistic):           0.000303
# Time:                        13:32:12   Log-Likelihood:                -45.247
# No. Observations:                  21   AIC:                             108.5
# Df Residuals:                      12   BIC:                             117.9
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         17.9461     20.696      0.867      0.403     -27.148      63.040
# disp           0.0060      0.025      0.239      0.815      -0.048       0.060
# hp            -0.0198      0.034     -0.582      0.572      -0.094       0.054
# drat           2.5188      3.016      0.835      0.420      -4.052       9.090
# wt            -3.7775      2.648     -1.427      0.179      -9.546       1.991
# vs            -1.0515      3.264     -0.322      0.753      -8.162       6.059
# am            -1.3970      3.242     -0.431      0.674      -8.460       5.666
# gear           3.2070      2.763      1.161      0.268      -2.814       9.228
# carb          -1.5672      1.508     -1.039      0.319      -4.852       1.718
# ==============================================================================
# Omnibus:                        1.254   Durbin-Watson:                   2.264
# Prob(Omnibus):                  0.534   Jarque-Bera (JB):                0.732
# Skew:                           0.454   Prob(JB):                        0.693
# Kurtosis:                       2.897   Cond. No.                     8.54e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.54e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#get coefficients
coefficients=coeff("MLR_using_VIF",multiple_reg_VIF.params)
coefficients
# Out:
#        Categorical_Linear_Regression  MLR_with_all_attributes  \
# const                       2.348026               -15.057502
# gear                        4.773026                 2.774741
# cyl                              NaN                 1.674058
# disp                             NaN                 0.005234
# hp                               NaN                 0.003330
# drat                             NaN                 3.002229
# wt                               NaN                -2.212533
# qsec                             NaN                 0.708473
# vs                               NaN                 2.264985
# am                               NaN                 4.422467
# carb                             NaN                -2.113711
#
#        MLR_after_standardization  MLR_after_outlier_treatment  MLR_after_RFE  \
# const                   2.598804                     2.598804      -6.703900
# gear                    2.774741                     2.774741       2.758848
# cyl                     1.674058                     1.674058            NaN
# disp                    0.636599                     0.636599            NaN
# hp                      0.217834                     0.217834            NaN
# drat                    1.590218                     1.590218            NaN
# wt                     -2.188170                    -2.188170      -6.099687
# qsec                    1.191935                     1.191935       2.091027
# vs                      2.264985                     2.264985      -3.392859
# am                      4.422467                     4.422467            NaN
# carb                   -2.113711                    -2.113711            NaN
#
#        MLR_using_VIF
# const      17.946132
# gear        3.206968
# cyl              NaN
# disp        0.005966
# hp         -0.019761
# drat        2.518836
# wt         -3.777485
# qsec             NaN
# vs         -1.051549
# am         -1.397019
# carb       -1.567169

# %% [markdown]
# Q 10

# %%
#get error metrics
scores = get_metrics(y_train_VIF,multiple_reg_VIF.predict( X_train_VIF),y_test_VIF,multiple_reg_VIF.predict(X_test_VIF),"MLR_using_VIF",scores)
scores
# Out:
# <ipython-input-31-684a30b8e91b>:18: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#                          Model  MAE_Train  MSE_Train  RMSE_Train  MAPE_Train  \
# 0      MLR_with_all_attributes   1.233768   2.769940    1.664314    6.808510
# 1    MLR_after_standardization   1.233768   2.769940    1.664314    6.808510
# 2  MLR_after_Outlier_treatment   1.155745   2.230477    1.493478    5.801718
# 3                MLR_after_RFE   1.700125   3.810251    1.951986    7.933231
# 4                MLR_using_VIF   1.607818   4.355147    2.086899    7.444411
#
#    MAE_Test   MSE_Test  RMSE_Test  MAPE_Test       R^2
# 0  4.193637  26.815954   5.178412  21.043919  0.913842
# 1  4.193637  26.815954   5.178412  21.043919  0.913842
# 2  5.051285  37.677355   6.138188  29.647128  0.932669
# 3  3.293632  11.847395   3.442004  18.455579  0.884980
# 4  2.962728  13.791923   3.713748  15.823922  0.868532
